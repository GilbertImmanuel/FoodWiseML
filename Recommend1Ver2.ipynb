# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import altair as alt
import random
import ast
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
interactions = pd.read_csv('drive/MyDrive/CapstoneML/RAW_interactions.csv')
recipes = pd.read_csv('drive/MyDrive/CapstoneML/RAW_recipes.csv')

# %%
interactions.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
#Only recipes with 2 or more interactions
interactions_filtered = interactions.groupby('recipe_id').filter(lambda x : len(x) >=2).sort_values(by = 'recipe_id')
recipes_filtered_reviews = interactions_filtered.recipe_id.unique()


# Extract and filterall ingredients and count their occurrences
ingredient_filter = recipes['ingredients'].str.lower().str.replace('[^\w\s]', '').str.split()
ingredient_flat = [word for sublist in ingredient_filter for ingredient in sublist for word in ingredient.split()]
ingredient_counts = pd.Series(ingredient_flat).value_counts()
common_keywords = ingredient_counts[ingredient_counts > 2000].index.tolist()

def filter_common_ingredients(data, common_keywords):
    ingredients_series = recipes['ingredients'].str.lower().str.replace('[^\w\s]', '').str.split(', ')
    ingredient_matrix = {key: [] for key in common_keywords}
    for recipe_ingredients in ingredients_series:
        flat_list = [item for item in recipe_ingredients]
        for key in common_keywords:
            ingredient_matrix[key].append(1 if any(key in ingredient for ingredient in flat_list) else 0)
    return pd.DataFrame(ingredient_matrix)

# Apply the filter function to get a DataFrame with binary indicators for common ingredients
ingredient_matrix = filter_common_ingredients(recipes, common_keywords)

# Now proceed with filtering recipes based on interactions and cooking times
interactions_filtered = interactions.groupby('recipe_id').filter(lambda x : len(x) >=2).sort_values(by = 'recipe_id')
recipes_filtered_reviews = interactions_filtered.recipe_id.unique()

# Keep only those with times in the interquantile range
q1 = recipes['minutes'].quantile(0.25)
q3 = recipes['minutes'].quantile(0.75)
iqr = q3 - q1

recipes_filtered_time = recipes[(recipes['minutes'] >= q1 - 1.5 * iqr) & (recipes['minutes'] <= q3 + 1.5 * iqr)].id.to_list()

# Intersect both restrictions
recipes_filtered = list(set(recipes_filtered_reviews).intersection(set(recipes_filtered_time)))

# Take 10k recipes at random
sample_size = 2000 # 2k to start for now
random.seed(1)
recipe_id_idx = random.sample(recipes_filtered, sample_size)

# Merge the data sets
merged_df = pd.merge(recipes, interactions, how = 'left', left_on ='id', right_on = 'recipe_id')

# Keep only the recipes and reviews for recipes in the recipe_id_idx
merged_df = merged_df[merged_df.recipe_id.isin(recipe_id_idx)]
merged_df.reset_index(drop=True, inplace=True)
merged_df['ingredients'] = merged_df['ingredients'].apply(lambda x: ast.literal_eval(x))
merged_df['nutrition'] = merged_df['nutrition'].apply(lambda x: ast.literal_eval(x))
merged_df['steps'] = merged_df['steps'].apply(lambda x: ast.literal_eval(x))
merged_df['tags'] = merged_df['tags'].apply(lambda x: ast.literal_eval(x))

merged_df.to_csv('clean_data.csv', index=False)

# %%
# from google.colab import files
# files.download('clean_data.csv')

# %%
merged_df_clean = pd.read_csv('clean_data.csv')

# %%
merged_df_clean.shape
# Out:
# (14788, 17)

# %%
merged_df_clean['ingredients'] = merged_df_clean['ingredients'].apply(lambda x: ast.literal_eval(x))
merged_df_clean['nutrition'] = merged_df_clean['nutrition'].apply(lambda x : ast.literal_eval(x))
merged_df_clean['steps'] = merged_df_clean['steps'].apply(lambda x : ast.literal_eval(x))
merged_df_clean['tags'] = merged_df_clean['tags'].apply(lambda x : ast.literal_eval(x))

# %% [markdown]
# ## Recommend Recipe based on Ingredients

# %%
def recipes_by_ingredients(data, ingredients_input):
    # Convert ingredients input to a set for faster operation
    ingredients_set = set(ingredients_input)

    # Define a function to count how many input ingredients are in each recipe
    def ingredient_match_count(recipe_ingredients):
        recipe_ingredients_set = set(recipe_ingredients)
        return len(ingredients_set.intersection(recipe_ingredients_set))

    # Apply the function to count matches and add a new column 'match_count'
    data['match_count'] = data['ingredients'].apply(ingredient_match_count)

    # Aggregate data to avoid duplicates and sort by 'match_count'
    aggregated_data = data.groupby('name').agg({'match_count': 'max'}).reset_index()
    top_recipes = aggregated_data.sort_values(by='match_count', ascending=False).head(10)
    return top_recipes

# %%
ingredients_input = ['chicken', 'salt', 'pepper', 'beef', 'cheese', 'carrot', 'potato', 'pepper']
top_recipe_names = recipes_by_ingredients(merged_df_clean, ingredients_input)
print(top_recipe_names)
# Out:
#                                                    name  match_count
# 322                            cheese   potato pancakes            4
# 652                                      easy beefaroni            3
# 1446                                  pureed watercress            3
# 372                   chicken in new orleans wine sauce            3
# 1576  seafood casserole  for those who don t like se...            3
# 624                                   donna s cole slaw            3
# 1488                                      rice tortitas            3
# 452                                 chunky italian soup            3
# 568              cube steak with gravy and potatoes  ww            3
# 1524                            root soup w blue cheese            3

# %% [markdown]
# ## Recomendation System

# %%
merged_df_clean = merged_df_clean.drop_duplicates(subset = 'recipe_id', keep = 'first')

# %%
#Prepare the data, keep only three cols
df = merged_df_clean[['name', 'ingredients','minutes','n_steps','n_ingredients']].copy()

#Create a list of unique ingredients
list_ingredients = list(set([ing for ingredients in df['ingredients'] for ing in ingredients]))

#Create matrix (recipes,ingredients) with zeros
ingredient_matrix = pd.DataFrame(0, index=df.index, columns=list_ingredients)

# %%
#populate the matrix
for i, ing_list in enumerate(df['ingredients']):
  ingredient_matrix.iloc[i, [list_ingredients.index(ing) for ing in ing_list]] = 1
ingredient_matrix
# Out:
#        unbleached cane sugar  whipped cream  sugar-free vanilla pudding mix  \
# 0                          0              0                               0
# 2                          0              0                               0
# 45                         0              0                               0
# 47                         0              0                               0
# 53                         0              0                               0
# ...                      ...            ...                             ...
# 14692                      0              0                               0
# 14694                      0              0                               0
# 14722                      0              0                               0
# 14773                      0              0                               0
# 14777                      0              0                               0
#
#        toasted sliced almonds  egg  amaretto  chocolate-covered coffee beans  \
# 0                           0    0         0                               0
# 2                           0    0         0                               0
# 45                          0    0         0                               0
# 47                          0    0         0                               0
# 53                          0    0         0                               0
# ...                       ...  ...       ...                             ...
# 14692                       0    1         0                               0
# 14694                       0    0         0                               0
# 14722                       0    0         0                               0
# 14773                       0    0         0                               0
# 14777                       0    1         0                               0
#
#        cream cheese with chives  caramel-flavored bits  kraft caramels  ...  \
# 0                             0                      0               0  ...
# 2                             0                      0               0  ...
# 45                            0                      0               0  ...
# 47                            0                      0               0  ...
# 53                            0                      0               0  ...
# ...                         ...                    ...             ...  ...
# 14692                         0                      0               0  ...
# 14694                         0                      0               0  ...
# 14722                         0                      0               0  ...
# 14773                         0                      0               0  ...
# 14777                         0                      0               0  ...
#
#        dried rubbed sage  radish  wagon wheel macaroni  bay leaves  \
# 0                      0       0                     0           0
# 2                      0       0                     0           0
# 45                     0       0                     0           0
# 47                     0       0                     0           0
# 53                     0       0                     0           0
# ...                  ...     ...                   ...         ...
# 14692                  0       0                     0           0
# 14694                  0       0                     0           0
# 14722                  0       0                     0           0
# 14773                  0       0                     0           0
# 14777                  0       0                     0           0
#
#        oyster mushroom  sea salt  roll  skim milk  pure vanilla extract  \
# 0                    0         0     0          0                     0
# 2                    0         0     0          0                     0
# 45                   0         0     0          0                     0
# 47                   0         0     0          0                     0
# 53                   0         0     0          0                     0
# ...                ...       ...   ...        ...                   ...
# 14692                0         0     0          0                     0
# 14694                0         0     0          0                     0
# 14722                0         0     0          0                     0
# 14773                0         0     0          0                     0
# 14777                0         0     0          0                     0
#
#        pure chile powder
# 0                      0
# 2                      0
# 45                     0
# 47                     0
# 53                     0
# ...                  ...
# 14692                  0
# 14694                  0
# 14722                  0
# 14773                  0
# 14777                  0
#
# [2000 rows x 2638 columns]

# %%
ingredient_matrix.sum(axis = 0)
# Out:
# unbleached cane sugar               1
# whipped cream                      11
# sugar-free vanilla pudding mix      1
# toasted sliced almonds              1
# egg                               138
#                                  ...
# sea salt                           27
# roll                                1
# skim milk                          28
# pure vanilla extract               13
# pure chile powder                   1
# Length: 2638, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
normalized_minutes = scaler.fit_transform(df['minutes'].values.reshape(-1,1))
normalized_n_steps = scaler.fit_transform(df['n_steps'].values.reshape(-1,1))
normalized_n_ingredients = scaler.fit_transform(df['n_ingredients'].values.reshape(-1,1))

df_normalized = df.copy()
df_normalized['minutes'] = normalized_minutes
df_normalized['n_steps'] = normalized_n_steps
df_normalized['n_ingredients'] = normalized_n_ingredients
df_normalized.reset_index(drop=True, inplace=True)

# %%
#Calculate the similarity for ingredients
ingredient_similarities = cosine_similarity(ingredient_matrix)

# %%
ingredient_similarities.shape
# Out:
# (2000, 2000)

# %%
#Calculate the distance for prep times

distances_minutes = []
for i in tqdm(range(len(df_normalized))):
  row_distances = []
  for j in range(len(df_normalized)):
    distance = euclidean([df_normalized.loc[i,'minutes']], [df_normalized.loc[j,'minutes']])
    row_distances.append(distance)
  distances_minutes.append(row_distances)
# Out:
# 100%|██████████| 2000/2000 [01:49<00:00, 18.21it/s]

# %%
#Calculate the distance for n_steps
from tqdm import tqdm
distances_n_steps = []
for i in tqdm(range(len(df_normalized))):
  row_distances = []
  for j in range(len(df_normalized)):
    distance = euclidean([df_normalized.loc[i,'n_steps']], [df_normalized.loc[j,'n_steps']])
    row_distances.append(distance)
  distances_n_steps.append(row_distances)
# Out:
# 100%|██████████| 2000/2000 [02:04<00:00, 16.06it/s]

# %%
#Calculate the distance for n_ingredients
from tqdm import tqdm
distances_n_ingredients = []
for i in tqdm(range(len(df_normalized))):
  row_distances = []
  for j in range(len(df_normalized)):
    distance = euclidean([df_normalized.loc[i,'n_ingredients']], [df_normalized.loc[j,'n_ingredients']])
    row_distances.append(distance)
  distances_n_ingredients.append(row_distances)
# Out:
# 100%|██████████| 2000/2000 [01:52<00:00, 17.75it/s]

# %%
# # Same function as the top, just to save lines

# def calculate_distances(df, column):
#   distances = []
#   for i in tqdm(range(len(df))):
#     for j in range(len(df)):
#       distance = euclidean([df.loc[i,column]], [df.loc[j,column]])
#       row_distances.append(distance)
#     distances.append(row_distances)

#   return distances

# %%
# distances_minutes = calculate_distances(df_normalized, 'minutes')
# distances_n_steps = calculate_distances(df_normalized, 'n_steps')
# distances_n_ingredients = calculate_distances(df_normalized, 'n_ingredients')

# %%
len(distances_minutes) , len(distances_n_steps), len(distances_n_ingredients)
# Out:
# (2000, 2000, 2000)

# %%
#Combine the similarity and distance scores; weight ingredients more
#All weights must add up to 1
weight_ingredients = 0.55
weight_minutes = 0.15
weight_n_steps = 0.15
weight_n_ingredients = 0.15
combined_scores = [[weight_ingredients*ingredient_similarities[i,j] \
                    +(weight_minutes)*(1/(1 + distances_minutes[i][j]))\
                    +(weight_n_ingredients)*(1/(1 + distances_n_ingredients[i][j]))\
                    +(weight_n_steps)*(1/(1 + distances_n_steps[i][j]))
                    for j in range(len(df_normalized))]
                   for i in range(len(df_normalized))]

df_scores = pd.DataFrame(combined_scores, index=df_normalized['name'],columns=df_normalized['name'])
#Export the scores
import gzip
with gzip.open('df_scores.csv.gz', 'wb') as f:
    df_scores.to_csv(f, index=True)

df_scores
# Out:
# name                                                pick me up  party chicken kabobs  \
# name
# pick me up  party chicken kabobs                                            1.000000
# say what   banana sandwich                                                  0.254858
# better than a can  homemade sloppy joes                                     0.203798
# buffalo wild wings  medium wing sauce copycat b...                          0.409053
# s wonderful carrot and raisin salad                                         0.478934
# ...                                                                              ...
# zucchini corn fritters                                                      0.296356
# zucchini oven   fries                                                       0.370198
# zucchini ribbons with basil butter                                          0.364703
# zucchini wheat germ burgers                                                 0.413322
# zucchini parmesan pancakes                                                  0.426787
#
# name                                                say what   banana sandwich  \
# name
# pick me up  party chicken kabobs                                      0.254858
# say what   banana sandwich                                            1.000000
# better than a can  homemade sloppy joes                               0.114166
# buffalo wild wings  medium wing sauce copycat b...                    0.224523
# s wonderful carrot and raisin salad                                   0.379012
# ...                                                                        ...
# zucchini corn fritters                                                0.171769
# zucchini oven   fries                                                 0.242694
# zucchini ribbons with basil butter                                    0.238326
# zucchini wheat germ burgers                                           0.220706
# zucchini parmesan pancakes                                            0.335450
#
# name                                                better than a can  homemade sloppy joes  \
# name
# pick me up  party chicken kabobs                                                   0.203798
# say what   banana sandwich                                                         0.114166
# better than a can  homemade sloppy joes                                            1.000000
# buffalo wild wings  medium wing sauce copycat b...                                 0.206293
# s wonderful carrot and raisin salad                                                0.153775
# ...                                                                                     ...
# zucchini corn fritters                                                             0.197664
# zucchini oven   fries                                                              0.148784
# zucchini ribbons with basil butter                                                 0.217920
# zucchini wheat germ burgers                                                        0.201816
# zucchini parmesan pancakes                                                         0.200730
#
# name                                                buffalo wild wings  medium wing sauce copycat by todd  \
# name
# pick me up  party chicken kabobs                                                             0.409053
# say what   banana sandwich                                                                   0.224523
# better than a can  homemade sloppy joes                                                      0.206293
# buffalo wild wings  medium wing sauce copycat b...                                           1.000000
# s wonderful carrot and raisin salad                                                          0.332565
# ...                                                                                               ...
# zucchini corn fritters                                                                       0.304180
# zucchini oven   fries                                                                        0.466270
# zucchini ribbons with basil butter                                                           0.324033
# zucchini wheat germ burgers                                                                  0.340231
# zucchini parmesan pancakes                                                                   0.374347
#
# name                                                s wonderful carrot and raisin salad  \
# name
# pick me up  party chicken kabobs                                               0.478934
# say what   banana sandwich                                                     0.379012
# better than a can  homemade sloppy joes                                        0.153775
# buffalo wild wings  medium wing sauce copycat b...                             0.332565
# s wonderful carrot and raisin salad                                            1.000000
# ...                                                                                 ...
# zucchini corn fritters                                                         0.229023
# zucchini oven   fries                                                          0.394786
# zucchini ribbons with basil butter                                             0.300448
# zucchini wheat germ burgers                                                    0.288376
# zucchini parmesan pancakes                                                     0.367230
#
# name                                                10  bars  \
# name
# pick me up  party chicken kabobs                    0.255009
# say what   banana sandwich                          0.314838
# better than a can  homemade sloppy joes             0.124737
# buffalo wild wings  medium wing sauce copycat b...  0.236425
# s wonderful carrot and raisin salad                 0.304380
# ...                                                      ...
# zucchini corn fritters                              0.195761
# zucchini oven   fries                               0.276326
# zucchini ribbons with basil butter                  0.374158
# zucchini wheat germ burgers                         0.251277
# zucchini parmesan pancakes                          0.322543
#
# name                                                15 minute chicken  broccoli  and rice dinner  \
# name
# pick me up  party chicken kabobs                                                        0.306795
# say what   banana sandwich                                                              0.263745
# better than a can  homemade sloppy joes                                                 0.144988
# buffalo wild wings  medium wing sauce copycat b...                                      0.418747
# s wonderful carrot and raisin salad                                                     0.308744
# ...                                                                                          ...
# zucchini corn fritters                                                                  0.316955
# zucchini oven   fries                                                                   0.394028
# zucchini ribbons with basil butter                                                      0.385178
# zucchini wheat germ burgers                                                             0.337934
# zucchini parmesan pancakes                                                              0.334122
#
# name                                                2 minute broccoli  \
# name
# pick me up  party chicken kabobs                             0.231737
# say what   banana sandwich                                   0.358236
# better than a can  homemade sloppy joes                      0.115512
# buffalo wild wings  medium wing sauce copycat b...           0.395669
# s wonderful carrot and raisin salad                          0.218091
# ...                                                               ...
# zucchini corn fritters                                       0.178598
# zucchini oven   fries                                        0.273244
# zucchini ribbons with basil butter                           0.266963
# zucchini wheat germ burgers                                  0.247035
# zucchini parmesan pancakes                                   0.251505
#
# name                                                3 step biscuits or how to break up with your girlfriend biscuits  \
# name
# pick me up  party chicken kabobs                                                             0.276539
# say what   banana sandwich                                                                   0.307654
# better than a can  homemade sloppy joes                                                      0.147077
# buffalo wild wings  medium wing sauce copycat b...                                           0.400340
# s wonderful carrot and raisin salad                                                          0.273298
# ...                                                                                               ...
# zucchini corn fritters                                                                       0.242646
# zucchini oven   fries                                                                        0.332592
# zucchini ribbons with basil butter                                                           0.327259
# zucchini wheat germ burgers                                                                  0.296089
# zucchini parmesan pancakes                                                                   0.282415
#
# name                                                30 minute chicken tamales  \
# name
# pick me up  party chicken kabobs                                     0.303811
# say what   banana sandwich                                           0.184086
# better than a can  homemade sloppy joes                              0.161355
# buffalo wild wings  medium wing sauce copycat b...                   0.265705
# s wonderful carrot and raisin salad                                  0.349045
# ...                                                                       ...
# zucchini corn fritters                                               0.182846
# zucchini oven   fries                                                0.373101
# zucchini ribbons with basil butter                                   0.287802
# zucchini wheat germ burgers                                          0.317203
# zucchini parmesan pancakes                                           0.234645
#
# name                                                ...  \
# name                                                ...
# pick me up  party chicken kabobs                    ...
# say what   banana sandwich                          ...
# better than a can  homemade sloppy joes             ...
# buffalo wild wings  medium wing sauce copycat b...  ...
# s wonderful carrot and raisin salad                 ...
# ...                                                 ...
# zucchini corn fritters                              ...
# zucchini oven   fries                               ...
# zucchini ribbons with basil butter                  ...
# zucchini wheat germ burgers                         ...
# zucchini parmesan pancakes                          ...
#
# name                                                zitumbuwa  banana fritters  \
# name
# pick me up  party chicken kabobs                                      0.363206
# say what   banana sandwich                                            0.433423
# better than a can  homemade sloppy joes                               0.137287
# buffalo wild wings  medium wing sauce copycat b...                    0.266840
# s wonderful carrot and raisin salad                                   0.421758
# ...                                                                        ...
# zucchini corn fritters                                                0.236873
# zucchini oven   fries                                                 0.410405
# zucchini ribbons with basil butter                                    0.297166
# zucchini wheat germ burgers                                           0.295230
# zucchini parmesan pancakes                                            0.361102
#
# name                                                zoobana  zucchini banana  bread  \
# name
# pick me up  party chicken kabobs                                           0.327801
# say what   banana sandwich                                                 0.291951
# better than a can  homemade sloppy joes                                    0.187376
# buffalo wild wings  medium wing sauce copycat b...                         0.286854
# s wonderful carrot and raisin salad                                        0.277508
# ...                                                                             ...
# zucchini corn fritters                                                     0.336277
# zucchini oven   fries                                                      0.425168
# zucchini ribbons with basil butter                                         0.267571
# zucchini wheat germ burgers                                                0.334925
# zucchini parmesan pancakes                                                 0.353620
#
# name                                                zucchini   onions with mozzarella cheese  \
# name
# pick me up  party chicken kabobs                                                    0.475713
# say what   banana sandwich                                                          0.260185
# better than a can  homemade sloppy joes                                             0.159089
# buffalo wild wings  medium wing sauce copycat b...                                  0.376791
# s wonderful carrot and raisin salad                                                 0.441609
# ...                                                                                      ...
# zucchini corn fritters                                                              0.339595
# zucchini oven   fries                                                               0.457620
# zucchini ribbons with basil butter                                                  0.454152
# zucchini wheat germ burgers                                                         0.410388
# zucchini parmesan pancakes                                                          0.519338
#
# name                                                zucchini appetizer squares  \
# name
# pick me up  party chicken kabobs                                      0.320225
# say what   banana sandwich                                            0.180885
# better than a can  homemade sloppy joes                               0.254585
# buffalo wild wings  medium wing sauce copycat b...                    0.350560
# s wonderful carrot and raisin salad                                   0.226098
# ...                                                                        ...
# zucchini corn fritters                                                0.359349
# zucchini oven   fries                                                 0.343633
# zucchini ribbons with basil butter                                    0.357012
# zucchini wheat germ burgers                                           0.481777
# zucchini parmesan pancakes                                            0.442006
#
# name                                                zucchini chicken  \
# name
# pick me up  party chicken kabobs                            0.347743
# say what   banana sandwich                                  0.294079
# better than a can  homemade sloppy joes                     0.195417
# buffalo wild wings  medium wing sauce copycat b...          0.306795
# s wonderful carrot and raisin salad                         0.332130
# ...                                                              ...
# zucchini corn fritters                                      0.309131
# zucchini oven   fries                                       0.448561
# zucchini ribbons with basil butter                          0.446510
# zucchini wheat germ burgers                                 0.314549
# zucchini parmesan pancakes                                  0.537223
#
# name                                                zucchini corn fritters  \
# name
# pick me up  party chicken kabobs                                  0.296356
# say what   banana sandwich                                        0.171769
# better than a can  homemade sloppy joes                           0.197664
# buffalo wild wings  medium wing sauce copycat b...                0.304180
# s wonderful carrot and raisin salad                               0.229023
# ...                                                                    ...
# zucchini corn fritters                                            1.000000
# zucchini oven   fries                                             0.321779
# zucchini ribbons with basil butter                                0.280706
# zucchini wheat germ burgers                                       0.466556
# zucchini parmesan pancakes                                        0.415598
#
# name                                                zucchini oven   fries  \
# name
# pick me up  party chicken kabobs                                 0.370198
# say what   banana sandwich                                       0.242694
# better than a can  homemade sloppy joes                          0.148784
# buffalo wild wings  medium wing sauce copycat b...               0.466270
# s wonderful carrot and raisin salad                              0.394786
# ...                                                                   ...
# zucchini corn fritters                                           0.321779
# zucchini oven   fries                                            1.000000
# zucchini ribbons with basil butter                               0.461493
# zucchini wheat germ burgers                                      0.413535
# zucchini parmesan pancakes                                       0.450515
#
# name                                                zucchini ribbons with basil butter  \
# name
# pick me up  party chicken kabobs                                              0.364703
# say what   banana sandwich                                                    0.238326
# better than a can  homemade sloppy joes                                       0.217920
# buffalo wild wings  medium wing sauce copycat b...                            0.324033
# s wonderful carrot and raisin salad                                           0.300448
# ...                                                                                ...
# zucchini corn fritters                                                        0.280706
# zucchini oven   fries                                                         0.461493
# zucchini ribbons with basil butter                                            1.000000
# zucchini wheat germ burgers                                                   0.329275
# zucchini parmesan pancakes                                                    0.487399
#
# name                                                zucchini wheat germ burgers  \
# name
# pick me up  party chicken kabobs                                       0.413322
# say what   banana sandwich                                             0.220706
# better than a can  homemade sloppy joes                                0.201816
# buffalo wild wings  medium wing sauce copycat b...                     0.340231
# s wonderful carrot and raisin salad                                    0.288376
# ...                                                                         ...
# zucchini corn fritters                                                 0.466556
# zucchini oven   fries                                                  0.413535
# zucchini ribbons with basil butter                                     0.329275
# zucchini wheat germ burgers                                            1.000000
# zucchini parmesan pancakes                                             0.396796
#
# name                                                zucchini parmesan pancakes
# name
# pick me up  party chicken kabobs                                      0.426787
# say what   banana sandwich                                            0.335450
# better than a can  homemade sloppy joes                               0.200730
# buffalo wild wings  medium wing sauce copycat b...                    0.374347
# s wonderful carrot and raisin salad                                   0.367230
# ...                                                                        ...
# zucchini corn fritters                                                0.415598
# zucchini oven   fries                                                 0.450515
# zucchini ribbons with basil butter                                    0.487399
# zucchini wheat germ burgers                                           0.396796
# zucchini parmesan pancakes                                            1.000000
#
# [2000 rows x 2000 columns]

# %%
#Select a recipe at random
recipe_name = df_normalized.loc[random.sample(range(len(df_normalized)),1),'name'].iloc[0]
recipe_name

#Recommend 5 similar recipes
similar_recipes_2 = df_scores[recipe_name].reset_index(drop=False).sort_values(by = recipe_name, ascending=False).iloc[1:5].name.tolist()
atts_recipe = df[df.name == recipe_name]
recommendations = [{'recipe':i,'minutes':df[df.name ==i].minutes.iloc[0],'n_steps':df[df.name==i].n_steps.iloc[0]
                    , 'n_ingredients':df[df.name==i].n_ingredients.iloc[0]} for i in similar_recipes_2]
recipe = {'recipe':recipe_name,'minutes':df[df.name ==recipe_name].minutes.iloc[0],'n_steps':df[df.name==recipe_name].n_steps.iloc[0]
                    , 'n_ingredients':df[df.name==recipe_name].n_ingredients.iloc[0]}

# %%
recipe
# Out:
# {'recipe': 'cantaloupe banana slush',
#  'minutes': 5,
#  'n_steps': 7,
#  'n_ingredients': 5}

# %%
recommendations
# Out:
# [{'recipe': 'swedish melon with red raspberry puree  melon och hallendessert',
#   'minutes': 10,
#   'n_steps': 12,
#   'n_ingredients': 5},
#  {'recipe': 'traditional irish coffee',
#   'minutes': 5,
#   'n_steps': 7,
#   'n_ingredients': 4},
#  {'recipe': 'banana caterpillars',
#   'minutes': 10,
#   'n_steps': 7,
#   'n_ingredients': 5},
#  {'recipe': 'zitumbuwa  banana fritters',
#   'minutes': 25,
#   'n_steps': 2,
#   'n_ingredients': 5}]
