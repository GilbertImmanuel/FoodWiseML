# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import altair as alt
import random
import ast
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
interactions = pd.read_csv('drive/MyDrive/CapstoneML/RAW_interactions.csv')
recipes = pd.read_csv('drive/MyDrive/CapstoneML/RAW_recipes.csv')

# %%
interactions.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
#Only recipes with 2 or more interactions
interactions_filtered = interactions.groupby('recipe_id').filter(lambda x : len(x) >=2).sort_values(by = 'recipe_id')
recipes_filtered_reviews = interactions_filtered.recipe_id.unique()


# Extract and filterall ingredients and count their occurrences
ingredient_filter = recipes['ingredients'].str.lower().str.replace('[^\w\s]', '').str.split()
ingredient_flat = [word for sublist in ingredient_filter for ingredient in sublist for word in ingredient.split()]
ingredient_counts = pd.Series(ingredient_flat).value_counts()
common_keywords = ingredient_counts[ingredient_counts > 2000].index.tolist()

def filter_common_ingredients(data, common_keywords):
    ingredients_series = recipes['ingredients'].str.lower().str.replace('[^\w\s]', '').str.split(', ')
    ingredient_matrix = {key: [] for key in common_keywords}
    for recipe_ingredients in ingredients_series:
        flat_list = [item for item in recipe_ingredients]
        for key in common_keywords:
            ingredient_matrix[key].append(1 if any(key in ingredient for ingredient in flat_list) else 0)
    return pd.DataFrame(ingredient_matrix)

# Apply the filter function to get a DataFrame with binary indicators for common ingredients
ingredient_matrix = filter_common_ingredients(recipes, common_keywords)

# Now proceed with filtering recipes based on interactions and cooking times
interactions_filtered = interactions.groupby('recipe_id').filter(lambda x : len(x) >=2).sort_values(by = 'recipe_id')
recipes_filtered_reviews = interactions_filtered.recipe_id.unique()

# Keep only those with times in the interquantile range
q1 = recipes['minutes'].quantile(0.25)
q3 = recipes['minutes'].quantile(0.75)
iqr = q3 - q1

recipes_filtered_time = recipes[(recipes['minutes'] >= q1 - 1.5 * iqr) & (recipes['minutes'] <= q3 + 1.5 * iqr)].id.to_list()

# Intersect both restrictions
recipes_filtered = list(set(recipes_filtered_reviews).intersection(set(recipes_filtered_time)))

# Take 10k recipes at random
sample_size = 5000 # 2k to start for now
random.seed(1)
recipe_id_idx = random.sample(recipes_filtered, sample_size)

# Merge the data sets
merged_df = pd.merge(recipes, interactions, how = 'left', left_on ='id', right_on = 'recipe_id')

# Keep only the recipes and reviews for recipes in the recipe_id_idx
merged_df = merged_df[merged_df.recipe_id.isin(recipe_id_idx)]
merged_df.reset_index(drop=True, inplace=True)
merged_df['ingredients'] = merged_df['ingredients'].apply(lambda x: ast.literal_eval(x))
merged_df['nutrition'] = merged_df['nutrition'].apply(lambda x: ast.literal_eval(x))
merged_df['steps'] = merged_df['steps'].apply(lambda x: ast.literal_eval(x))
merged_df['tags'] = merged_df['tags'].apply(lambda x: ast.literal_eval(x))

merged_df.to_csv('clean_data.csv', index=False)

# %%
# from google.colab import files
# files.download('clean_data.csv')

# %%
merged_df_clean = pd.read_csv('clean_data.csv')

# %%
merged_df_clean.shape
# Out:
# (35623, 17)

# %%
merged_df_clean['ingredients'] = merged_df_clean['ingredients'].apply(lambda x: ast.literal_eval(x))
merged_df_clean['nutrition'] = merged_df_clean['nutrition'].apply(lambda x : ast.literal_eval(x))
merged_df_clean['steps'] = merged_df_clean['steps'].apply(lambda x : ast.literal_eval(x))
merged_df_clean['tags'] = merged_df_clean['tags'].apply(lambda x : ast.literal_eval(x))

# %% [markdown]
# ## Recommend Recipe based on Ingredients

# %%
def recipes_by_ingredients(data, ingredients_input):
    # Convert ingredients input to a set for faster operation
    ingredients_set = set(ingredients_input)

    # Define a function to count how many input ingredients are in each recipe
    def ingredient_match_count(recipe_ingredients):
        recipe_ingredients_set = set(recipe_ingredients)
        return len(ingredients_set.intersection(recipe_ingredients_set))

    # Apply the function to count matches and add a new column 'match_count'
    data['match_count'] = data['ingredients'].apply(ingredient_match_count)

    # Aggregate data to avoid duplicates and sort by 'match_count'
    aggregated_data = data.groupby('name').agg({'match_count': 'max'}).reset_index()
    top_recipes = aggregated_data.sort_values(by='match_count', ascending=False).head(10)
    return top_recipes

# %%
ingredients_input = ['chicken', 'salt', 'pepper', 'beef', 'cheese', 'carrot', 'potato', 'pepper']
top_recipe_names = recipes_by_ingredients(merged_df_clean, ingredients_input)
print(top_recipe_names)
# Out:
#                                                    name  match_count
# 848                            cheese   potato pancakes            4
# 2479                    joyce s cheese n chicken dinner            4
# 3802               root vegetables casserole for winter            4
# 3607                                  pureed watercress            3
# 3137                                    nutty wild rice            3
# 3961                                         shell soup            3
# 630          broiled flounder with puffy cheese topping            3
# 4249                      steph s savory stewed chicken            3
# 1285                        cottage pie simply the best            3
# 1864  frango  moda do alentejana  chicken with potat...            3

# %% [markdown]
# ## Recomendation System

# %%
merged_df_clean = merged_df_clean.drop_duplicates(subset = 'recipe_id', keep = 'first')

# %%
#Prepare the data, keep only three cols
df = merged_df_clean[['name', 'ingredients','minutes','n_steps','n_ingredients']].copy()

#Create a list of unique ingredients
list_ingredients = list(set([ing for ingredients in df['ingredients'] for ing in ingredients]))

#Create matrix (recipes,ingredients) with zeros
ingredient_matrix = pd.DataFrame(0, index=df.index, columns=list_ingredients)

# %%
#populate the matrix
for i, ing_list in enumerate(df['ingredients']):
  ingredient_matrix.iloc[i, [list_ingredients.index(ing) for ing in ing_list]] = 1
ingredient_matrix
# Out:
#        cucumber  canned pineapple  black cherries  whole chicken  \
# 0             0                 0               0              0
# 2             0                 0               0              0
# 45            0                 0               0              0
# 49            0                 0               0              0
# 54            0                 0               0              0
# ...         ...               ...             ...            ...
# 35590         0                 0               0              0
# 35592         0                 0               0              0
# 35595         0                 0               0              0
# 35606         0                 0               0              0
# 35621         0                 0               0              0
#
#        mexican blend cheese  minced clams  red bell peppers  \
# 0                         0             0                 0
# 2                         0             0                 0
# 45                        0             0                 0
# 49                        0             0                 0
# 54                        0             0                 0
# ...                     ...           ...               ...
# 35590                     0             0                 0
# 35592                     0             0                 0
# 35595                     0             0                 0
# 35606                     0             0                 0
# 35621                     0             0                 0
#
#        whipped cream cheese  lime peel  seasoned pepper  ...  chevre cheese  \
# 0                         0          0                0  ...              0
# 2                         0          0                0  ...              0
# 45                        0          0                0  ...              0
# 49                        0          0                0  ...              0
# 54                        0          0                0  ...              0
# ...                     ...        ...              ...  ...            ...
# 35590                     0          0                0  ...              0
# 35592                     0          0                0  ...              0
# 35595                     0          0                0  ...              0
# 35606                     0          0                0  ...              0
# 35621                     0          0                0  ...              0
#
#        chive & onion cream cheese  tap water  special k cereal  syrup  \
# 0                               0          0                 0      0
# 2                               0          0                 0      0
# 45                              0          0                 0      0
# 49                              0          0                 0      0
# 54                              0          0                 0      0
# ...                           ...        ...               ...    ...
# 35590                           0          0                 0      0
# 35592                           0          0                 0      0
# 35595                           0          0                 0      0
# 35606                           0          0                 0      0
# 35621                           0          0                 0      0
#
#        roma tomato  morton tender quick salt  beef t-bone steaks  broth  \
# 0                0                         0                   0      0
# 2                0                         0                   0      0
# 45               0                         0                   0      0
# 49               0                         0                   0      0
# 54               0                         0                   0      0
# ...            ...                       ...                 ...    ...
# 35590            0                         0                   0      0
# 35592            0                         0                   0      0
# 35595            0                         0                   0      0
# 35606            0                         0                   0      0
# 35621            0                         0                   0      0
#
#        madras curry powder
# 0                        0
# 2                        0
# 45                       0
# 49                       0
# 54                       0
# ...                    ...
# 35590                    0
# 35592                    0
# 35595                    0
# 35606                    0
# 35621                    0
#
# [5000 rows x 4001 columns]

# %%
ingredient_matrix.sum(axis = 0)
# Out:
# cucumber                    63
# canned pineapple             1
# black cherries               1
# whole chicken                6
# mexican blend cheese        11
#                             ..
# roma tomato                  4
# morton tender quick salt     1
# beef t-bone steaks           1
# broth                        4
# madras curry powder          3
# Length: 4001, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
normalized_minutes = scaler.fit_transform(df['minutes'].values.reshape(-1,1))
normalized_n_steps = scaler.fit_transform(df['n_steps'].values.reshape(-1,1))
normalized_n_ingredients = scaler.fit_transform(df['n_ingredients'].values.reshape(-1,1))

df_normalized = df.copy()
df_normalized['minutes'] = normalized_minutes
df_normalized['n_steps'] = normalized_n_steps
df_normalized['n_ingredients'] = normalized_n_ingredients
df_normalized.reset_index(drop=True, inplace=True)

# %%
#Calculate the similarity for ingredients
ingredient_similarities = cosine_similarity(ingredient_matrix)

# %%
ingredient_similarities.shape
# Out:
# (5000, 5000)

# %%
#Calculate the distance for prep times

distances_minutes = []
for i in tqdm(range(len(df_normalized))):
  row_distances = []
  for j in range(len(df_normalized)):
    distance = euclidean([df_normalized.loc[i,'minutes']], [df_normalized.loc[j,'minutes']])
    row_distances.append(distance)
  distances_minutes.append(row_distances)
# Out:
# 100%|██████████| 5000/5000 [11:29<00:00,  7.25it/s]

# %%
#Calculate the distance for n_steps
from tqdm import tqdm
distances_n_steps = []
for i in tqdm(range(len(df_normalized))):
  row_distances = []
  for j in range(len(df_normalized)):
    distance = euclidean([df_normalized.loc[i,'n_steps']], [df_normalized.loc[j,'n_steps']])
    row_distances.append(distance)
  distances_n_steps.append(row_distances)
# Out:
# 100%|██████████| 5000/5000 [11:28<00:00,  7.26it/s]

# %%
#Calculate the distance for n_ingredients
from tqdm import tqdm
distances_n_ingredients = []
for i in tqdm(range(len(df_normalized))):
  row_distances = []
  for j in range(len(df_normalized)):
    distance = euclidean([df_normalized.loc[i,'n_ingredients']], [df_normalized.loc[j,'n_ingredients']])
    row_distances.append(distance)
  distances_n_ingredients.append(row_distances)
# Out:
# 100%|██████████| 5000/5000 [11:23<00:00,  7.32it/s]

# %%
# # Same function as the top, just to save lines

# def calculate_distances(df, column):
#   distances = []
#   for i in tqdm(range(len(df))):
#     for j in range(len(df)):
#       distance = euclidean([df.loc[i,column]], [df.loc[j,column]])
#       row_distances.append(distance)
#     distances.append(row_distances)

#   return distances

# %%
# distances_minutes = calculate_distances(df_normalized, 'minutes')
# distances_n_steps = calculate_distances(df_normalized, 'n_steps')
# distances_n_ingredients = calculate_distances(df_normalized, 'n_ingredients')

# %%
len(distances_minutes) , len(distances_n_steps), len(distances_n_ingredients)
# Out:
# (5000, 5000, 5000)

# %%
#Combine the similarity and distance scores; weight ingredients more
#All weights must add up to 1
weight_ingredients = 0.50  #0.50 #0.55
weight_minutes = 0.20 #0.20 #0.15
weight_n_steps = 0.10 #0.10 #0.15
weight_n_ingredients = 0.20 #0.20 #0.15
combined_scores = [[weight_ingredients*ingredient_similarities[i,j] \
                    +(weight_minutes)*(1/(1 + distances_minutes[i][j]))\
                    +(weight_n_ingredients)*(1/(1 + distances_n_ingredients[i][j]))\
                    +(weight_n_steps)*(1/(1 + distances_n_steps[i][j]))
                    for j in range(len(df_normalized))]
                   for i in range(len(df_normalized))]

df_scores = pd.DataFrame(combined_scores, index=df_normalized['name'],columns=df_normalized['name'])
#Export the scores
import gzip
with gzip.open('df_scores.csv.gz', 'wb') as f:
    df_scores.to_csv(f, index=True)

df_scores
# Out:
# name                                        pick me up  party chicken kabobs  \
# name
# pick me up  party chicken kabobs                                    1.000000
# say what   banana sandwich                                          0.255011
# creamy   vegan potato leek soup                                     0.381335
# free toe  pie                                                       0.320246
# it s too easy  pork chops   rice casserole                          0.254803
# ...                                                                      ...
# zucchini with pasta                                                 0.614745
# zucchini feta casserole                                             0.173404
# zucchini parmesan pancakes                                          0.462223
# zuppa di pesce  cioppino  or fish stew                              0.241466
# zwiebelfleisch  onion beef                                          0.379781
#
# name                                        say what   banana sandwich  \
# name
# pick me up  party chicken kabobs                              0.255011
# say what   banana sandwich                                    1.000000
# creamy   vegan potato leek soup                               0.216971
# free toe  pie                                                 0.254521
# it s too easy  pork chops   rice casserole                    0.230017
# ...                                                                ...
# zucchini with pasta                                           0.262093
# zucchini feta casserole                                       0.128405
# zucchini parmesan pancakes                                    0.333392
# zuppa di pesce  cioppino  or fish stew                        0.140915
# zwiebelfleisch  onion beef                                    0.195355
#
# name                                        creamy   vegan potato leek soup  \
# name
# pick me up  party chicken kabobs                                   0.381335
# say what   banana sandwich                                         0.216971
# creamy   vegan potato leek soup                                    1.000000
# free toe  pie                                                      0.381104
# it s too easy  pork chops   rice casserole                         0.340476
# ...                                                                     ...
# zucchini with pasta                                                0.412271
# zucchini feta casserole                                            0.237909
# zucchini parmesan pancakes                                         0.350428
# zuppa di pesce  cioppino  or fish stew                             0.293014
# zwiebelfleisch  onion beef                                         0.354124
#
# name                                        free toe  pie  \
# name
# pick me up  party chicken kabobs                 0.320246
# say what   banana sandwich                       0.254521
# creamy   vegan potato leek soup                  0.381104
# free toe  pie                                    1.000000
# it s too easy  pork chops   rice casserole       0.413765
# ...                                                   ...
# zucchini with pasta                              0.334599
# zucchini feta casserole                          0.225553
# zucchini parmesan pancakes                       0.358618
# zuppa di pesce  cioppino  or fish stew           0.229838
# zwiebelfleisch  onion beef                       0.270425
#
# name                                        it s too easy  pork chops   rice casserole  \
# name
# pick me up  party chicken kabobs                                              0.254803
# say what   banana sandwich                                                    0.230017
# creamy   vegan potato leek soup                                               0.340476
# free toe  pie                                                                 0.413765
# it s too easy  pork chops   rice casserole                                    1.000000
# ...                                                                                ...
# zucchini with pasta                                                           0.269156
# zucchini feta casserole                                                       0.307940
# zucchini parmesan pancakes                                                    0.243220
# zuppa di pesce  cioppino  or fish stew                                        0.333186
# zwiebelfleisch  onion beef                                                    0.418206
#
# name                                        wild game   moose sloppy joes  \
# name
# pick me up  party chicken kabobs                                 0.340476
# say what   banana sandwich                                       0.328910
# creamy   vegan potato leek soup                                  0.412322
# free toe  pie                                                    0.366335
# it s too easy  pork chops   rice casserole                       0.259892
# ...                                                                   ...
# zucchini with pasta                                              0.368388
# zucchini feta casserole                                          0.148999
# zucchini parmesan pancakes                                       0.429786
# zuppa di pesce  cioppino  or fish stew                           0.154953
# zwiebelfleisch  onion beef                                       0.306105
#
# name                                        better than a can  homemade sloppy joes  \
# name
# pick me up  party chicken kabobs                                           0.233538
# say what   banana sandwich                                                 0.132289
# creamy   vegan potato leek soup                                            0.306484
# free toe  pie                                                              0.197709
# it s too easy  pork chops   rice casserole                                 0.238337
# ...                                                                             ...
# zucchini with pasta                                                        0.230621
# zucchini feta casserole                                                    0.416856
# zucchini parmesan pancakes                                                 0.229434
# zuppa di pesce  cioppino  or fish stew                                     0.327820
# zwiebelfleisch  onion beef                                                 0.258172
#
# name                                        buffalo wild wings  medium wing sauce copycat by todd  \
# name
# pick me up  party chicken kabobs                                                     0.472782
# say what   banana sandwich                                                           0.234828
# creamy   vegan potato leek soup                                                      0.337815
# free toe  pie                                                                        0.335817
# it s too easy  pork chops   rice casserole                                           0.399474
# ...                                                                                       ...
# zucchini with pasta                                                                  0.429413
# zucchini feta casserole                                                              0.216709
# zucchini parmesan pancakes                                                           0.414550
# zuppa di pesce  cioppino  or fish stew                                               0.227676
# zwiebelfleisch  onion beef                                                           0.406999
#
# name                                        cheeseburger stuffed  french bread  \
# name
# pick me up  party chicken kabobs                                      0.406050
# say what   banana sandwich                                            0.208244
# creamy   vegan potato leek soup                                       0.456632
# free toe  pie                                                         0.429677
# it s too easy  pork chops   rice casserole                            0.321008
# ...                                                                        ...
# zucchini with pasta                                                   0.507825
# zucchini feta casserole                                               0.200450
# zucchini parmesan pancakes                                            0.417101
# zuppa di pesce  cioppino  or fish stew                                0.259553
# zwiebelfleisch  onion beef                                            0.370545
#
# name                                        hershey s triple layer cheesecake  \
# name
# pick me up  party chicken kabobs                                     0.182889
# say what   banana sandwich                                           0.096637
# creamy   vegan potato leek soup                                      0.132506
# free toe  pie                                                        0.171853
# it s too easy  pork chops   rice casserole                           0.128556
# ...                                                                       ...
# zucchini with pasta                                                  0.176371
# zucchini feta casserole                                              0.228319
# zucchini parmesan pancakes                                           0.152114
# zuppa di pesce  cioppino  or fish stew                               0.139265
# zwiebelfleisch  onion beef                                           0.165217
#
# name                                        ...  \
# name                                        ...
# pick me up  party chicken kabobs            ...
# say what   banana sandwich                  ...
# creamy   vegan potato leek soup             ...
# free toe  pie                               ...
# it s too easy  pork chops   rice casserole  ...
# ...                                         ...
# zucchini with pasta                         ...
# zucchini feta casserole                     ...
# zucchini parmesan pancakes                  ...
# zuppa di pesce  cioppino  or fish stew      ...
# zwiebelfleisch  onion beef                  ...
#
# name                                        zucchini ribbons with basil butter  \
# name
# pick me up  party chicken kabobs                                      0.391648
# say what   banana sandwich                                            0.260050
# creamy   vegan potato leek soup                                       0.441808
# free toe  pie                                                         0.484247
# it s too easy  pork chops   rice casserole                            0.398012
# ...                                                                        ...
# zucchini with pasta                                                   0.545576
# zucchini feta casserole                                               0.220999
# zucchini parmesan pancakes                                            0.490428
# zuppa di pesce  cioppino  or fish stew                                0.289895
# zwiebelfleisch  onion beef                                            0.343436
#
# name                                        zucchini salad with tomatoes  \
# name
# pick me up  party chicken kabobs                                0.473797
# say what   banana sandwich                                      0.320183
# creamy   vegan potato leek soup                                 0.306454
# free toe  pie                                                   0.274697
# it s too easy  pork chops   rice casserole                      0.240423
# ...                                                                  ...
# zucchini with pasta                                             0.578423
# zucchini feta casserole                                         0.271058
# zucchini parmesan pancakes                                      0.392906
# zuppa di pesce  cioppino  or fish stew                          0.218095
# zwiebelfleisch  onion beef                                      0.272273
#
# name                                        zucchini soup  zucchini spread  \
# name
# pick me up  party chicken kabobs                 0.461721         0.508660
# say what   banana sandwich                       0.241522         0.281890
# creamy   vegan potato leek soup                  0.381979         0.441691
# free toe  pie                                    0.441356         0.330962
# it s too easy  pork chops   rice casserole       0.287079         0.279518
# ...                                                   ...              ...
# zucchini with pasta                              0.619051         0.719397
# zucchini feta casserole                          0.216115         0.242758
# zucchini parmesan pancakes                       0.478354         0.439495
# zuppa di pesce  cioppino  or fish stew           0.259249         0.271004
# zwiebelfleisch  onion beef                       0.376983         0.328921
#
# name                                        zucchini wheat germ burgers  \
# name
# pick me up  party chicken kabobs                               0.432005
# say what   banana sandwich                                     0.242224
# creamy   vegan potato leek soup                                0.274979
# free toe  pie                                                  0.343574
# it s too easy  pork chops   rice casserole                     0.306643
# ...                                                                 ...
# zucchini with pasta                                            0.378543
# zucchini feta casserole                                        0.296152
# zucchini parmesan pancakes                                     0.425538
# zuppa di pesce  cioppino  or fish stew                         0.238636
# zwiebelfleisch  onion beef                                     0.325273
#
# name                                        zucchini with pasta  \
# name
# pick me up  party chicken kabobs                       0.614745
# say what   banana sandwich                             0.262093
# creamy   vegan potato leek soup                        0.412271
# free toe  pie                                          0.334599
# it s too easy  pork chops   rice casserole             0.269156
# ...                                                         ...
# zucchini with pasta                                    1.000000
# zucchini feta casserole                                0.247039
# zucchini parmesan pancakes                             0.487142
# zuppa di pesce  cioppino  or fish stew                 0.274238
# zwiebelfleisch  onion beef                             0.304196
#
# name                                        zucchini feta casserole  \
# name
# pick me up  party chicken kabobs                           0.173404
# say what   banana sandwich                                 0.128405
# creamy   vegan potato leek soup                            0.237909
# free toe  pie                                              0.225553
# it s too easy  pork chops   rice casserole                 0.307940
# ...                                                             ...
# zucchini with pasta                                        0.247039
# zucchini feta casserole                                    1.000000
# zucchini parmesan pancakes                                 0.249203
# zuppa di pesce  cioppino  or fish stew                     0.359933
# zwiebelfleisch  onion beef                                 0.260679
#
# name                                        zucchini parmesan pancakes  \
# name
# pick me up  party chicken kabobs                              0.462223
# say what   banana sandwich                                    0.333392
# creamy   vegan potato leek soup                               0.350428
# free toe  pie                                                 0.358618
# it s too easy  pork chops   rice casserole                    0.243220
# ...                                                                ...
# zucchini with pasta                                           0.487142
# zucchini feta casserole                                       0.249203
# zucchini parmesan pancakes                                    1.000000
# zuppa di pesce  cioppino  or fish stew                        0.212870
# zwiebelfleisch  onion beef                                    0.515889
#
# name                                        zuppa di pesce  cioppino  or fish stew  \
# name
# pick me up  party chicken kabobs                                          0.241466
# say what   banana sandwich                                                0.140915
# creamy   vegan potato leek soup                                           0.293014
# free toe  pie                                                             0.229838
# it s too easy  pork chops   rice casserole                                0.333186
# ...                                                                            ...
# zucchini with pasta                                                       0.274238
# zucchini feta casserole                                                   0.359933
# zucchini parmesan pancakes                                                0.212870
# zuppa di pesce  cioppino  or fish stew                                    1.000000
# zwiebelfleisch  onion beef                                                0.302337
#
# name                                        zwiebelfleisch  onion beef
# name
# pick me up  party chicken kabobs                              0.379781
# say what   banana sandwich                                    0.195355
# creamy   vegan potato leek soup                               0.354124
# free toe  pie                                                 0.270425
# it s too easy  pork chops   rice casserole                    0.418206
# ...                                                                ...
# zucchini with pasta                                           0.304196
# zucchini feta casserole                                       0.260679
# zucchini parmesan pancakes                                    0.515889
# zuppa di pesce  cioppino  or fish stew                        0.302337
# zwiebelfleisch  onion beef                                    1.000000
#
# [5000 rows x 5000 columns]

# %%
#Select a recipe at random
recipe_name = df_normalized.loc[random.sample(range(len(df_normalized)),1),'name'].iloc[0]
recipe_name

#Recommend 5 similar recipes
similar_recipes_2 = df_scores[recipe_name].reset_index(drop=False).sort_values(by = recipe_name, ascending=False).iloc[1:5].name.tolist()
atts_recipe = df[df.name == recipe_name]
recommendations = [{'recipe':i,'minutes':df[df.name ==i].minutes.iloc[0],'n_steps':df[df.name==i].n_steps.iloc[0]
                    , 'n_ingredients':df[df.name==i].n_ingredients.iloc[0]} for i in similar_recipes_2]
recipe = {'recipe':recipe_name,'minutes':df[df.name ==recipe_name].minutes.iloc[0],'n_steps':df[df.name==recipe_name].n_steps.iloc[0]
                    , 'n_ingredients':df[df.name==recipe_name].n_ingredients.iloc[0]}

# %%
recipe
# Out:
# {'recipe': 'best backfin crab cakes',
#  'minutes': 25,
#  'n_steps': 8,
#  'n_ingredients': 12}

# %%
recommendations
# Out:
# [{'recipe': 'classic old bay crab cakes',
#   'minutes': 20,
#   'n_steps': 5,
#   'n_ingredients': 12},
#  {'recipe': 'sweettreats ultimate chocolate chip cookies',
#   'minutes': 25,
#   'n_steps': 9,
#   'n_ingredients': 12},
#  {'recipe': 'california roll burgers with wasabi mayonnaise',
#   'minutes': 20,
#   'n_steps': 5,
#   'n_ingredients': 12},
#  {'recipe': 'supper easy turkey stroganoff',
#   'minutes': 25,
#   'n_steps': 10,
#   'n_ingredients': 12}]
